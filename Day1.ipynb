# %% [markdown]
# ## Day 1: Part 1 - Trebuchet?!
#
# Something is wrong with global snow production, and you've been selected to take a look. The Elves have even given you a map; on it, they've used stars to mark the top fifty locations that are likely to be having problems.
#
# You've been doing this long enough to know that to restore snow operations, you need to check all fifty stars by December 25th.
#
# Collect stars by solving puzzles. Two puzzles will be made available on each day in the Advent calendar; the second puzzle is unlocked when you complete the first. Each puzzle grants one star. Good luck!
#
# You try to ask why they can't just use a weather machine ("not powerful enough") and where they're even sending you ("the sky") and why your map looks mostly blank ("you sure ask a lot of questions") and hang on did you just say the sky ("of course, where do you think snow comes from") when you realize that the Elves are already loading you into a trebuchet ("please hold still, we need to strap you in").
#
# As they're making the final adjustments, they discover that their calibration document (your puzzle input) has been amended by a very young Elf who was apparently just excited to show off her art skills. Consequently, the Elves are having trouble reading the values on the document.
#
# The newly-improved calibration document consists of lines of text; each line originally contained a specific calibration value that the Elves now need to recover. On each line, the calibration value can be found by combining the first digit and the last digit (in that order) to form a single two-digit number.
#
# For example:
#
#     1abc2
#     pqr3stu8vwx
#     a1b2c3d4e5f
#     treb7uchet
#
# In this example, the calibration values of these four lines are 12, 38, 15, and 77. Adding these together produces 142.
#
# Consider your entire calibration document. What is the sum of all of the calibration values?

# %% [markdown]
# ### Test on sample code

# %%
# load in sample puzzle input
file_path = 'data/calibration_values_test.txt' 

try:
    with open(file_path, 'r') as file:
        puzzle_input_test = file.read()
except FileNotFoundError:
    print(f"File not found: {file_path}")
    puzzle_input_test = None

# %%
print(puzzle_input_test)
# Out:
# 1abc2
# pqr3stu8vwx
# a1b2c3d4e5f
# treb7uchet

# %%
# empty list to store calibration values
calibration_values_test = []

# split string into separate lines
for line in puzzle_input_test.split('\n'):
    if line and len(line) >= 2:
        # extract first digit -  note if only one digit in line this will be first and last
        first_number = next((char for char in line if char.isdigit()), None)
        
        # extract last digit - note if only one digit in line this will be first and last 
        last_number = next((char for char in reversed(line) if char.isdigit()), None)
        
        # merge the two digits into one integer value
        calibration_value = int(first_number) * 10 + int(last_number) 
        
        # append to our empty list
        calibration_values_test.append(calibration_value)
        
# sum the values        
test_answer = sum(calibration_values_test)
print(test_answer)

# validation
if test_answer == 142:
    print("Test passed!")
else:
    print("Sorry. Wrong answer. Keep trying!")
# Out:
# 142
# Test passed!

# %% [markdown]
# ### Attempted solution

# %%
file_path = 'data/calibration_values.txt'  # Replace with the actual path to your file

try:
    with open(file_path, 'r') as file:
        puzzle_input = file.read()
except FileNotFoundError:
    print(f"File not found: {file_path}")
    puzzle_input = None

# %%
print(puzzle_input)
# Out:
# shrzvdcghblt21
# sixdddkcqjdnzzrgfourxjtwosevenhg9
# threevt1onegxgvc9flk
# 7dmqzksnlcpbsqkzqlfour1four
# 4seven9gdlnhqxfseven94five
# nldeightwoshgnsjnzmbkbxcxltsqtstrgdmvqvxbfour6six
# 87mmlvfr4
# six1vvrlxx8two
# znmfvdlhvjtwo9three4tzjqcfcgnsevenccvnsjczlpm
# 5sixninesixnh
# three1tbtwo
# five9seventwobqsjqzxkptkhsix1
# 74fivemn
# sevenfivetsglnine8three
# spnvnfkbv4eightlmdkxmsfour574eight
# one4four2fivedcpqjmgc8
# two6sevensix33
# krc34five
# doneight64qgc251four7
# vpjthc6
# threethxbtffhbfourfive3
# onetwo5
# 1sevenngjqsfrptq8stgzxgjfp
# 1576sevenninefhfqd4
# nine4nine9ninefive
# zp8sfveight9twotgbvscb
# eight27nrzmfsix7nine7two
# gsfivefivepmq9nineftndvlcph
# znggdvvkjthreethree79eight4
# 7twofivethree7ninevtspmbfxnr
# four9twoxthdxdc7two1
# 8ddcmt87xhkqjbgtmkpjlkhd7sevenfour
# 4four6
# seven5tmzksnsv9six
# 6fivesixlxfrqbkfive
# seven9one8jxqkhbfppt
# hxsbgn6four7
# 7pglchqndpnknhvcnkthreefour2
# bkkfjq6dklbppfvgsshgrbmtwo97
# 66eightsix3nine652
# ...

# %%
calibration_values = []

for line in puzzle_input.split('\n'):
    if line and len(line) >= 2:
        first_number = next((char for char in line if char.isdigit()), None)
        last_number = next((char for char in reversed(line) if char.isdigit()), None)
        calibration_value = int(first_number) * 10 + int(last_number)  
        calibration_values.append(calibration_value)

# sum the values        
answer = sum(calibration_values)
print(answer)
# Out:
# 55538

# %% [markdown]
# ![day1_part_1.JPG](attachment:647e672f-6bd0-4314-9282-22bb2bc2aca5.JPG)

# %% [markdown]
# ### Part Two

# %% [markdown]
# Your calculation isn't quite right. It looks like some of the digits are actually spelled out with letters: one, two, three, four, five, six, seven, eight, and nine also count as valid "digits".
#
# Equipped with this new information, you now need to find the real first and last digit on each line. For example:
#
#     two1nine
#     eightwothree
#     abcone2threexyz
#     xtwone3four
#     4nineeightseven2
#     zoneight234
#     7pqrstsixteen
#
# In this example, the calibration values are 29, 83, 13, 24, 42, 14, and 76. Adding these together produces 281.

# %% [markdown]
# ### Test

# %%
# load in sample puzzle input
file_path = 'data/calibration_values_test2.txt' 

try:
    with open(file_path, 'r') as file:
        puzzle_input_test2 = file.read()
except FileNotFoundError:
    print(f"File not found: {file_path}")
    puzzle_input_test2 = None

# %%
print(puzzle_input_test2)
# Out:
# two1nine
# eightwothree
# abcone2threexyz
# xtwone3four
# 4nineeightseven2
# zoneight234
# 7pqrstsixteen

# %%
sum_calibration_values = 0 

for line in puzzle_input_test2.split('\n'):
    
    calibration_values = []
    
    for i,c in enumerate(line):
        if c.isdigit():
            calibration_values.append(c)
            
        for d, val in enumerate(['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']):
            if line[i:].startswith(val):
                calibration_values.append(str(d+1)) 
    sum_calibration_values += int(calibration_values[0] + calibration_values[-1])

print(sum_calibration_values)     

# validation
if sum_calibration_values == 281:
    print("Test passed!")
else:
    print("Sorry. Wrong answer. Keep trying!")
# Out:
# 281
# Test passed!

# %% [markdown]
# ### Attempted Solution

# %%
file_path = 'data/calibration_values.txt'  # Replace with the actual path to your file

try:
    with open(file_path, 'r') as file:
        puzzle_input2 = file.read()
except FileNotFoundError:
    print(f"File not found: {file_path}")
    puzzle_input = None

# %%
sum_calibration_values = 0 

for line in puzzle_input2.split('\n'):
    
    calibration_values = []
    
    for i,c in enumerate(line):
        
        if c.isdigit():
            calibration_values.append(c)
            
        for d, val in enumerate(['one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine']):
            if line[i:].startswith(val):
                calibration_values.append(str(d+1)) 
                
    sum_calibration_values += int(calibration_values[0] + calibration_values[-1])

print(f'The sum of the calibration values is {sum_calibration_values}.')
# Out:
# The sum of the calibration values is 54875.
